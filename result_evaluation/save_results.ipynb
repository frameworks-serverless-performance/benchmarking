# %% [markdown]
# # Saving the parsed and calculated results
# Since parsing and calculating the results can take quite a while, here they are saved to a csv so that they can be loaded quickly

# %%
from parse_and_calculate_results import get_test_results

# %%
results = get_test_results("../results")
# Out:
# Response codes for compute are all 200 OK
# Response data for compute is correct
# Response codes for compute are all 200 OK
# Response data for compute is correct
# Response codes for compute are all 200 OK
# Response data for compute is correct
# Response codes for compute are all 200 OK
# Response data for compute is correct
# Response codes for compute are all 200 OK
# Response data for compute is correct
# Response codes for compute are all 200 OK
# Response data for compute is correct
# Response codes for compute are all 200 OK
# Response data for compute is correct
# Response codes for compute are all 200 OK
# Response data for compute is correct
# Response codes for compute are all 200 OK
# Response data for compute is correct
# Response codes for echo are all 200 OK
# Response data for echo is correct
# Response codes for echo are all 200 OK
# Response data for echo is correct
# Response codes for echo are all 200 OK
# Response data for echo is correct
# ...

# %%
results.to_csv("../results.csv", index=False)

# %%
results = get_test_results("../serverless_results")
# Out:
# Response codes for compute are all 200 OK
# Response data for compute is correct
# Response codes for echo are all 200 OK
# Response data for echo is correct
# Response codes for get_price are all 200 OK
# Response data for get_price is correct
# Response codes for parse are all 200 OK
# Response data for parse is correct
# Response codes for query are all 200 OK
# Response data for query is correct
# Response codes for query are all 200 OK
# Response data for query is correct
# Response codes for query are all 200 OK
# Response data for query is correct
# Response codes for query are all 200 OK
# Response data for query is correct
# Response codes for query are all 200 OK
# Response data for query is correct
# Response codes for query are all 200 OK
# Response data for query is correct
# Response codes for query are all 200 OK
# Response data for query is correct
# Response codes for query are all 200 OK
# Response data for query is correct
# Response codes for query are all 200 OK
# ...

# %%
results.to_csv("../serverless_results.csv", index=False)
